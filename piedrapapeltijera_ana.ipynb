# %% [markdown]
# Reglas del Juego "Piedra, Papel y Tijera":
# Dos jugadores eligen una de las tres opciones: "Piedra", "Papel" o "Tijera".
#     ->Las reglas para determinar al ganador son:
#     -Piedra vence a Tijera.
#     -Tijera vence a Papel.
#     -Papel vence a Piedra.
#     ->El jugador que gana una ronda obtiene un punto.
#     ->El juego continúa hasta que un jugador haya acumulado 3 puntos, convirtiéndose en el ganador.
#
#     Pistas para las alumnas:
#     1. Comienza por definir el número de puntos objetivo que se deben alcanzar para ganar el juego.
#     2. Implementa una función que obtenga la elección del jugador y valide que sea una de las opciones válidas ("Piedra", "Papel" o "Tijera").
#     3. Utiliza un bucle `while` para llevar un registro de los puntos de cada jugador y continuar el juego hasta que se alcance el número de puntos objetivo.
#     4. Genera una elección aleatoria para el segundo jugador (la computadora) utilizando el módulo `random`.
#     5. Determina al ganador de cada ronda y actualiza los puntos correspondientes.
#     6. Verifica si algún jugador ha alcanzado el número de puntos objetivo y finalicen el juego cuando eso suceda.

# %%
import random
options = ['Rock','Paper','Scissor']
print("Welcome to Rock-Paper-Scissor's Game!")
points_player_human = 0
points_player_computer = 0


while (points_player_human != 3) and (points_player_computer != 3):
        print("Write an option: Rock, Paper or Scissor:")
        
        player_human = input("Type Player 1 option:").capitalize()
        print("player human option: ", player_human)

        if player_human not in options:
            print("Invalid option, please try again")
            continue

        player_computer = random.choice(options)
        print("player computer option: ", player_computer)

        if player_human == player_computer:
            print("It is a draw! Play again!")
            continue

        if player_human == "Rock":
            if player_computer == "Scissor":
                print("Player Human Won!")
                points_player_human = points_player_human+1
            else:
                print("Player Computer Won!")
                points_player_computer = points_player_computer+1

        if player_human == "Scissor": 
            if player_computer == "Paper":
                print("Player Human Won!")
                points_player_human = points_player_human+1
            else:
                print("Player Computer Won!")
                points_player_computer = points_player_computer+1
            
        if player_human == "Paper":
            if player_computer == "Rock":
                print("Player Human Won!")
                points_player_human = points_player_human+1
            else:
                print("Player Computer Won!")
                points_player_computer = points_player_computer+1

        print("Human Points:",points_player_human, "Computer Points:",points_player_computer)
        if points_player_human == 3:
          print("Player Human is the WINNER!")
        elif points_player_computer == 3:
            print("Player Computer is the WINNER")
# Out:
# Welcome to Rock-Paper-Scissor's Game!
# Write an option: Rock, Paper or Scissor:
# player human option:  Rock
# player computer option:  Paper
# Player Computer Won!
# Human Points: 0 Computer Points: 1
# Write an option: Rock, Paper or Scissor:
# player human option:  Paper
# player computer option:  Paper
# It is a draw! Play again!
# Write an option: Rock, Paper or Scissor:
# player human option:  Rock
# player computer option:  Scissor
# Player Human Won!
# Human Points: 1 Computer Points: 1
# Write an option: Rock, Paper or Scissor:
# player human option:  Scissor
# player computer option:  Paper
# Player Human Won!
# Human Points: 2 Computer Points: 1
# Write an option: Rock, Paper or Scissor:
# player human option:  Paper
# player computer option:  Scissor
# Player Computer Won!
# Human Points: 2 Computer Points: 2
# Write an option: Rock, Paper or Scissor:
# player human option:  Rock
# player computer option:  Scissor
# Player Human Won!
# Human Points: 3 Computer Points: 2
# Player Human is the WINNER!

# %%
#Rock‑Paper‑Scissors Game

import random
options = ['Rock','Paper','Scissor']
print("Welcome to Rock-Paper-Scissor's Game!")
points_player_human = 0
points_player_computer = 0


while (points_player_human != 3) and (points_player_computer != 3):
        print("Write an option: Rock, Paper or Scissor:")
        print("Player Human Points:",points_player_human)
        print("Player Computer Points:",points_player_computer)
        
        player_human = input("Type Player 1 option:").capitalize()
        print("player human option: ", player_human)

        if player_human not in options:
            print("Invalid option, please try again")
            continue

        player_computer = random.choice(options)
        print("player computer option: ", player_computer)

        if player_human == player_computer:
            print("It is a draw! Play again!")
            continue

        if player_human == "Rock":
            if player_computer == "Scissor":
                print("Player Human Won!")
                points_player_human = points_player_human+1
            else:
                print("Player Computer Won!")
                points_player_computer = points_player_computer+1
            continue

        if player_human == "Scissor": 
            if player_computer == "Paper":
                print("Player Human Won!")
                points_player_human = points_player_human+1
            else:
                print("Player Computer Won!")
                points_player_computer = points_player_computer+1
            continue
            
        if player_human == "Paper":
            if player_computer == "Rock":
                print("Player Human Won!")
                points_player_human = points_player_human+1
            else:
                print("Player Computer Won!")
                points_player_computer = points_player_computer+1
            continue

print("Total Player Human Points:",points_player_human)
print("Total Player Computer Points:",points_player_computer)
